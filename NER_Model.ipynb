# %% [markdown]
# <a href="https://colab.research.google.com/github/templas3324/NER-model-project/blob/main/NER_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 우신사 리뷰 개체명 인식 모델 제작

# %% [markdown]
# # 1. 문제 상황 정의
# 최근 인공지능(AI) 및 딥 러닝 기술이 상용화되면서 어느 기업이든 분야를 막론하고 이를 활용하여 서비스 개발 및 개선에 지대한 관심을 보이고 있습니다. 특히 자연어 처리(NLP) 분야는 음성인식, 검색최적화, 텍스트분류 등 클라이언트가 더욱 쉽게 서비스에 접근할 수 있도록 만드는 기술인 개체명인식(NER)이 크게 주목 받고 있습니다. 이에 우리는 국내 최대 온라인 의류 쇼핑몰 중 하나인 WUSINSA의 상품 리뷰 댓글을 개체명인식(NER)으로 처리하고 속성별로 분류하여, 향후 클라이언트의 검색 편의성을 제고할 수 있는 모델을 만들고자 합니다.

# %% [markdown]
# # 2. 데이터 수집 및 탐색적 데이터 분석(EDA)

# %% [markdown]
# ## 2-1. 데이터 수집
# 데이터는 별도의 웹 크롤러 프로그램을 통해 txt 파일로 수집하였습니다. 최대한 일반적이고 풍부한 표본을 수집하기 위해 리뷰 댓글이 100개 이상인 상품들을 상위로 하여 수집하였으며, 댓글의 내용이 한 상품으로만 치우치는 것을 방지하기 위하여 총 45개의 세부 카테고리별로 일정 비율에 의해 추출하였습니다. 총 4500여 개의 표본이 수집되었으나, 모델 학습을 위해 팀원들이 일일이 텍스트에 태깅작업을 해야하므로 프로젝트 기간을 고려해 이중 1500여 개의 데이터만 사용하기로 결정하였습니다.

# %% [markdown]
# ## 2-2. 탐색적 데이터 분석(EDA)

# %%
import pandas as pd

train = pd.read_csv("train.csv")

# %%
train.head()
# Out:
#                                               리뷰 텍스트
# 0  생각보다 무난해서 더 좋았던것 같아요 ! 뭔가 디테일이 많이 튈거라고 생각해서 걱정했는데
# 1  사진에 보이는 색상처럼 괜찮은 독특한 블루색입니다 기모가 쨩쨩해서 춥진 않을듯합니다...
# 2                    재질도좋고 촉감도 좋습니다~ 배송 역시 빠르고 마니파세요
# 3               교복에 입기 정말 무난한 후드집업 ㅎㅎ 사이즈도 넉넉하니 귀여워요
# 4             생각보다 조금 얇은 느낌이긴 한데 그래서 여름에 입기 좋은 것 같아요

# %%
train.tail()
# Out:
#                                                  리뷰 텍스트
# 1574        제가 가슴이 좀 있는편이어서 한사이즈 크게 샀는데 원하는 사이즈에 핏이 였음요
# 1575  스몰로 샀는데도 넉넉한 기장, 품, 핏입니다. 오버핏 확실하고 무겁습니다. 생각보다...
# 1576        유튜버분의 착용샷을 보고 구매했는데 받아보니 색감이 선명하고 편하고 이쁩니다!
# 1577                        너무 이쁘고 패셔너블하네오 무조건 사시는거 추천!
# 1578  실측사이즈만 봤을때 작을까봐 걱정했는데 오버핏으로나와서 안에 껴입기도 좋고 요즘날씨...

# %% [markdown]
# 리뷰 텍스트는 보통 온라인에서 사용하는 방식으로 작성되었습니다. 따라서 띄어쓰기나 맞춤법이 제대로 지켜지지 않는 상태로 작성되며, 외래어와 은어, 신조어, 이모티콘 등의 사용이 빈번하게 일어납니다. 또한 영어 텍스트와는 달리 한국어 텍스트는 조사의 사용이 빈번하기 때문에 띄어쓰기를 기준으로 토큰화(Tokenization)할 경우 '사이즈가'라는 토큰과 '사이즈는'이라는 토큰을 다른 단어로 인식하는 문제가 발생하게 됩니다.

# %% [markdown]
# # 3. 데이터 전처리
# 앞서 언급한 문제들로 인해 우선 맞춤법과 띄어쓰기를 교정해줄 필요가 있으며, 이를 바탕으로 일정 수준 교정된 텍스트를 형태소 기준으로 토큰화해야만 조사를 분리할 수 있다.

# %%
# 필요 패키지 다운로드 및 한국어 토큰화에 필요한 KoNLPy

# Java 설치 
# !apt-get update 
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev 

# !pip3 install JPype1-py3  # JAVA와 Python 연결
# !pip3 install konlpy # KoNLPy 설치
# !JAVA_HOME="C:\Program Files\Java\jdk1.8.0_291" #본인 pc의 jdk 설치 경로

# !bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# 리눅스 통해 콘솔창에서 실행할 수 있도록 스크립트가 함수로 묶어서 배포하는 스크립트

# %%
# 맞춤법, 띄어쓰기 교정을 위한 Hanspell

# - 파이썬의 pyhanspell 라이브러리는 네이버 맞춤법 검사기를 이용한 한글 맞춤법 검사 라이브러리입니다.
# - 맞춤법 검사 성공 여부
# - 검사 전과 후 문장 반환
# - 맞춤법 오류 총 갯수
# - 총 요청 시간
# - 교정 결과 비교


# !pip3 install git+https://github.com/ssut/py-hanspell.git

# %%
# hanspell 설치 확인
from hanspell import spell_checker

sent = "맞춤법 틀리면 외 않되? 쓰고싶은대로쓰면돼지 "
spelled_sent = spell_checker.check(sent)
print(spelled_sent) # 맞춤법 교정 과정 정보

hanspell_sent = spelled_sent.checked # 맞춤법 결과 반환해서 저장
print(hanspell_sent)
# Out:
# Checked(result=True, original='맞춤법 틀리면 외 않되? 쓰고싶은대로쓰면돼지 ', checked='맞춤법 틀리면 왜 안돼? 쓰고 싶은 대로 쓰면 되지', errors=2, words=OrderedDict([('맞춤법', 0), ('틀리면', 0), ('왜', 1), ('안돼?', 1), ('쓰고', 1), ('싶은', 1), ('대로', 1), ('쓰면', 1), ('되지', 1)]), time=0.7868034839630127)
# 맞춤법 틀리면 왜 안돼? 쓰고 싶은 대로 쓰면 되지

# %%
from konlpy.tag import Okt #한국어 형태소 분석기
from konlpy.tag import Kkma #한국어 형태소 분석기
from konlpy.tag import Mecab #한국어 형태소 분석기
from hanspell import spell_checker #한국어 맞춤법 교정기

import pandas as pd
import numpy as np # 난수 시드값 입력 위함
from sklearn.model_selection import train_test_split # 학습용 데이터셋과 테스트용 데이터셋 분기 위함.
from tqdm import tqdm # 진행 상황 바를 표시하여주는 라이브러리.
from collections import Counter # 등장 단어 빈도수 계산 위함.

# %% [markdown]
# 'reviewData.txt'파일은 코랩 세션 저장소에 업로드 해둬야 하며, read_csv 메서드로 파일을 읽어왔습니다. 이때 구분자는 \t를 사용합니다.
#
# head()를 통해 상위 5개 데이터를 읽어오면 잘 저장된 것을 확인할 수 있습니다.

# %%
rawData = pd.read_csv('reviewData.txt', delimiter = "\t")
rawData.head()
# Out:
#      하위분류  ...                                             리뷰 텍스트
# 0  긴팔 티셔츠  ...                     사이즈도 넉넉하게 잘 맞고 이쁘네요 재구매의향있습니다.
# 1  긴팔 티셔츠  ...  마크 곤잘레스는 여름티셔츠도 잘 입어서 브랜드에 믿음이 생겨서 긴팔도 주문했는데 원...
# 2  긴팔 티셔츠  ...                    옷 너무 이쁩니다. 레이어드 하기에도 너무 좋은거같아요.
# 3  긴팔 티셔츠  ...             가벼운 긴팔 하나 사고 싶었는데 마크곤잘레스 디자인 정말 이쁘네요ㄷㄷ
# 4  긴팔 티셔츠  ...                       이렇게 이쁜옷을 2만원도 안되게 사서 너무 좋아요!
#
# [5 rows x 15 columns]

# %%
print(rawData.shape) # 행,열 개수 확인
print(rawData.isnull().sum()) # 어떤 열에 null값이 있는지 출력
# Out:
# (4513, 15)
# 하위분류       0
# 상품명        0
# 브랜드명       0
# 가격         0
# 판매량       10
# 리뷰 수       0
# 연령대       20
# 전체 평점      0
# 사이즈 전체     0
# 밝기 전체      0
# 색깔 전체      0
# 제품 URL     0
# 제품 이미지     0
# 개인 평점      0
# 리뷰 텍스트     0
# dtype: int64

# %% [markdown]
# rawData는 총 4513행 15열의 데이터를 가지고 있습니다.
#
# 학습용 데이터셋을 만들고 학습용 데이터의 지도학습을 위한 태깅 작업을 하기 위해서는 이중 일부 데이터만 추려낼 필요가 있습니다.

# %%
data = rawData.iloc[::2] #인덱스가 짝수인 행만 선택하여 data 변수에 저장 (행 번호를 기준으로 행 데이터 추출)
data.shape # 행이 절반으로 줄어들었습니다.
# Out:
# (2257, 15)

# %%
data.to_csv("data.csv", index = None) # 파일로 내보내면서 기존에 남아있는 인덱스는 무시하도록 합니다.

# %%
data = pd.read_csv("data.csv")
data.tail() # head()를 통해 하위 5개 데이터를 읽어오면 행이 절반으로 줄어들고 잘 저장된 것을 확인할 수 있습니다.
# Out:
#      하위분류  ...                                             리뷰 텍스트
# 2252   장갑  ...            이뻐용 따뜻하게 착용할 수 있을 것 같구 살짝 따갑지만 이뻐서 괜찮아요
# 2253   장갑  ...  패딩이나 플리스 집업 안에 반팔만 입고 다니는데 긴팔은 싫을때 이 핸드워머 하나 해...
# 2254   장갑  ...                    거칠지만 따듯하니 좋아요~ 자주 착용하고 나갈 것 같아용
# 2255   장갑  ...               이쁘고 따뜻해요. 근데 보풀이 잘 일어나용ㅠ 그래도 나쁘지 않아요
# 2256   장갑  ...             생각보다 많이 안까슬거고 이뻐요! 엄지손가락 부분도 딱 맞고 좋습니당
#
# [5 rows x 15 columns]

# %% [markdown]
# 해당 데이터의 전처리는 한국어 사용자가 인터넷 환경에서 사용하는 자연어라는 특성을 고려하여 처리해주어야 합니다.

# %%
# 불필요한 컬럼 삭제 

data = data['리뷰 텍스트']
data.to_csv('data_filtered.csv', index = None)

# %%
data = pd.read_csv('data_filtered.csv')
data.head()
# Out:
#                                             리뷰 텍스트
# 0                   사이즈도 넉넉하게 잘 맞고 이쁘네요 재구매의향있습니다.
# 1                  옷 너무 이쁩니다. 레이어드 하기에도 너무 좋은거같아요.
# 2                     이렇게 이쁜옷을 2만원도 안되게 사서 너무 좋아요!
# 3                  친구 생일 선물로 사줬는데 너무너무 좋아해서 뿌듯합니다!
# 4  핏이도 예쁘고 스트라이프라서 어깨도 넓어보이네요 귀여운 남친룩으로 입기 좋을거 같아요

# %%
# train, test 데이터셋을 분기 합니다.

np.random.seed(1000) # 동일한 결과 얻기 위해 시드값은 1000으로 설정합니다.

train, test = train_test_split(data, test_size=0.3) # 학습용 데이터와 테스트 데이터를 7 대 3 비율로 분리합니다.
train.to_csv("train.csv", index = None)
test.to_csv("test.csv", index = None)
print(train.shape)
print(test.shape)
# Out:
# (1579, 1)
# (678, 1)

# %%
train.head()
# Out:
#                                                  리뷰 텍스트
# 2214  생각보다 무난해서 더 좋았던것 같아요 ! 뭔가 디테일이 많이 튈거라고 생각해서 걱정했는데
# 53    사진에 보이는 색상처럼 괜찮은 독특한 블루색입니다 기모가 쨩쨩해서 춥진 않을듯합니다...
# 255                     재질도좋고 촉감도 좋습니다~ 배송 역시 빠르고 마니파세요
# 443                교복에 입기 정말 무난한 후드집업 ㅎㅎ 사이즈도 넉넉하니 귀여워요
# 766              생각보다 조금 얇은 느낌이긴 한데 그래서 여름에 입기 좋은 것 같아요

# %%
test.head()
# Out:
#                                                  리뷰 텍스트
# 528   좋아용 ㅎㅎ 보세 인터넷 쇼핑몰에서 싼거 3만원짜리? 시켰다가 퀄 개구려서 반품하고...
# 1884                         여자친구가 입는다고 샀는데 딱 맞는다고 하네요!
# 882   진짜 너무 이쁜데 너무 짧아요... 155보다 작으셔야 일상생활 가능할것 같아요 계...
# 508      아주 가성비로 잘산거 같습니다. 너무 맘에들어요. 환절기에 자주 입을 것 같습니다.
# 126                  생각보다 끈이 좀 흐물거려서 조심해야 할 듯 리본 묶으니 이쁨

# %%
train = pd.read_csv("train.csv")

# %% [markdown]
# ## 3-1. 맞춤법 교정 처리 (Py-Hanspell)

# %%
train_checked = train['리뷰 텍스트']

for i in tqdm(range(len(train))): 
  result_train = spell_checker.check(train['리뷰 텍스트'][i]) 
  train_checked[i] = result_train.as_dict()['checked'] 

#tqdm() 모듈을 통해 맞춤법교정 진행율을 체크합니다.
# Out:
# 100%|██████████| 1579/1579 [06:28<00:00,  4.06it/s]

# %%
train.head() # 처리 전
# Out:
#                                               리뷰 텍스트
# 0  생각보다 무난해서 더 좋았던것 같아요 ! 뭔가 디테일이 많이 튈거라고 생각해서 걱정했는데
# 1  사진에 보이는 색상처럼 괜찮은 독특한 블루색입니다 기모가 쨩쨩해서 춥진 않을듯합니다...
# 2                    재질도좋고 촉감도 좋습니다~ 배송 역시 빠르고 마니파세요
# 3               교복에 입기 정말 무난한 후드집업 ㅎㅎ 사이즈도 넉넉하니 귀여워요
# 4             생각보다 조금 얇은 느낌이긴 한데 그래서 여름에 입기 좋은 것 같아요

# %%
train_checked.head() # 처리 후 맞춤법 교정 처리가 된 것을 확인 할 수 있습니다.
# Out:
# 0    생각보다 무난해서 더 좋았던 것 같아요! 뭔가 디테일이 많이 튈 거라고 생각해서 걱...
# 1    사진에 보이는 색상처럼 괜찮은 독특한 블루색입니다 기모가 쨩쨩해서 춥진 않을듯합니다...
# 2                    재질도 좋고 촉감도 좋습니다~ 배송 역시 빠르고 많이 파세요
# 3                 교복에 입기 정말 무난한 후드집업 ㅎㅎ 사이즈도 넉넉하니 귀여워요
# 4               생각보다 조금 얇은 느낌이긴 한데 그래서 여름에 입기 좋은 것 같아요
# Name: 리뷰 텍스트, dtype: object

# %%
train_checked.to_csv("train_checked.csv", index = None) # 맞춤법 교정된 파일을 엑셀 파일로 저장합니다.

# %%
train = pd.read_csv("train_checked.csv")
train.head()
# Out:
#                                               리뷰 텍스트
# 0  생각보다 무난해서 더 좋았던 것 같아요! 뭔가 디테일이 많이 튈 거라고 생각해서 걱...
# 1  사진에 보이는 색상처럼 괜찮은 독특한 블루색입니다 기모가 쨩쨩해서 춥진 않을듯합니다...
# 2                  재질도 좋고 촉감도 좋습니다~ 배송 역시 빠르고 많이 파세요
# 3               교복에 입기 정말 무난한 후드집업 ㅎㅎ 사이즈도 넉넉하니 귀여워요
# 4             생각보다 조금 얇은 느낌이긴 한데 그래서 여름에 입기 좋은 것 같아요

# %% [markdown]
# ## 3-2. 토큰화(Tokenization)(Okt 형태소 분석기)
# Okt, Kkma, Mecab 각 한국어 형태소 분석기의 결과를 비교했습니다.

# %%
okt = Okt()
print('Okt 형태소 분석 :',okt.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('Okt 품사 태깅 :',okt.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('Okt 명사 추출 :',okt.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# Okt 형태소 분석 : ['열심히', '코딩', '한', '당신', ',', '연휴', '에는', '여행', '을', '가봐요']
# Okt 품사 태깅 : [('열심히', 'Adverb'), ('코딩', 'Noun'), ('한', 'Josa'), ('당신', 'Noun'), (',', 'Punctuation'), ('연휴', 'Noun'), ('에는', 'Josa'), ('여행', 'Noun'), ('을', 'Josa'), ('가봐요', 'Verb')]
# Okt 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
kkma = Kkma()
print('Kkma 형태소 분석 :',kkma.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('Kkma 품사 태깅 :',kkma.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('Kkma 명사 추출 :',kkma.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# Kkma 형태소 분석 : ['열심히', '코딩', '하', 'ㄴ', '당신', ',', '연휴', '에', '는', '여행', '을', '가보', '아요']
# Kkma 품사 태깅 : [('열심히', 'MAG'), ('코딩', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('당신', 'NP'), (',', 'SP'), ('연휴', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('여행', 'NNG'), ('을', 'JKO'), ('가보', 'VV'), ('아요', 'EFN')]
# Kkma 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
mecab = Mecab()
print('Mecab 형태소 분석 : ', mecab.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('Mecab 형태소 분석 : ', mecab.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('Mecab 형태소 분석 : ', mecab.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# Mecab 형태소 분석 :  ['열심히', '코딩', '한', '당신', ',', '연휴', '에', '는', '여행', '을', '가', '봐요']
# Mecab 형태소 분석 :  [('열심히', 'MAG'), ('코딩', 'NNG'), ('한', 'XSA+ETM'), ('당신', 'NP'), (',', 'SC'), ('연휴', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('여행', 'NNG'), ('을', 'JKO'), ('가', 'VV'), ('봐요', 'EC+VX+EC')]
# Mecab 형태소 분석 :  ['코딩', '당신', '연휴', '여행']

# %% [markdown]
# 비교해본 결과 Okt가 데이터에 대해 가장 직관적인 토큰화를 구현하여 주므로 Okt 형태소 분석기를 사용하기로 결정하였습니다.

# %%
okt = Okt()

train_tokenized = []

for i in tqdm(range(len(train))): 
  train_tokenized.append(okt.morphs(train['리뷰 텍스트'][i]))
# Out:
# 100%|██████████| 1579/1579 [00:13<00:00, 120.30it/s]

# %%
print(train_tokenized)
# Out:
# [['생각', '보다', '무난', '해서', '더', '좋았던것', '같아요', '!', '뭔가', '디테', '일이', '많이', '튈거라고', '생각', '해서', '걱정', '했는데'], ['사진', '에', '보이는', '색상', '처럼', '괜찮은', '독특한', '블루', '색', '입니다', '기모', '가', '쨩쨩해', '서', '춥진', '않을듯', '합니다', '.', '티셔츠', '안', '에', '받쳐', '입으려면', '노', '기모', '가', '좋을듯'], ['재질', '도', '좋고', '촉감', '도', '좋습니다', '~', '배송', '역시', '빠르고', '마니', '파세요'], ['교복', '에', '입기', '정말', '무난', '한', '후드', '집업', 'ㅎㅎ', '사이즈', '도', '넉넉하니', '귀여워요'], ['생각', '보다', '조금', '얇은', '느낌이긴', '한데', '그래서', '여름', '에', '입기', '좋은', '것', '같아요'], ['아니', '슬리퍼', '가', '이렇게', '예뻐도', '돼', '나', '만', '신고', '싶다', '진짜', '너무', '예뻐요'], ['사이즈', '적당하고', '따뜻합니다', '.', '추천', '합니다', '.', '좋네요'], ['저렴하게', '득템', '했습니다', '.', '코듀', '로', '이', '스커트', '를', '사고싶어', '보다가', '저렴해서', '혹시', '나', '했는데', '받아', '보고', '완전', '만족', '입니다', '.', '^^'], ['생각', '보다', '너', '~~~~~~', '무', '작아요', '기본', '1', '사이즈', '업햇', '는데', '이건', '2', '사이즈', '업', '필요하겟네요'], ['부드럽고', '두께', '는', '적당해요', '디자인', '깔끔하고', '하나', '쯤', '있어도', '좋을꺼', '같아요'], ['굉장히', '도톰하고', '따뜻해요', '엄청', '커서', '몸', '이', '커', '보이', '기는', '하지만', '귀여워', '보여요'], ['걸', '을', '때', '편하구', '운동화', '에', '포인트', '가', '들어가있어', '넘', '넘', '이뻐요', 'ㅠ', '̑̈', 'ㅠ', '̑̈'], ['편하고', '좋습니다', '다만', '재봉', '선', '이', '있어서', '불편하실', '수도', '있어요', '저', '는', '편하게', '쓰고', '있습니다'], ['사이즈', '도', '딱', '맞고', '옷', '도', '너무', '이쁘네요', '옷', '이', '좀', '많이', '얇기', '더', '하고요', '그리고', '사은', '품', '에', '핫팩', '있길래', '주문', '해봤는데', '이미', '쓴', '걸', '로', '오네용', '..'], ['그냥', '반', '팔', '입', '고', '낄려고', '샀어요', '퀄리티', '는', '가격', '정도', '에요', '딱', '~'], ['옷', '이', '좋습니다', '잘', '입고', '다니고', '있어요', '~', '감사합니다'], ['아주', '편하고', '좋아요', '입기도', '편하고', '아주', '시원해요', '미스', '는', '여름', '옷', '을', '겨울', '에', '산', '멍청한', '내', '실수'], ['보통', '후드', '집업', '크게', '입을려고', '라지', '사는데', '이건', '리뷰', '보고', '긴가민가하면서', '엠', '시켰는데', '널럴하', '니', '딱', '원하는', '핏이', '에여', '!!!'], ['사이즈', '딱', '적당하고여', '174', '정도', '되시는', '분', '은', 'L', '정도', '가', '딱임다'], ['엄청', '따뜻해요', '.', '근데', 'm', '은', '허리', '가', '조금', '큰', '것', '같아요', '.', 'S', '사시길', '추천', '!'], ['치마', '길이', '도', '적당하게', '오고', '입으니까', '이쁜거', '같아요', '~'], ['어깨', '가', '좀', '많이', '좁아', '보이긴', '합니다만', '미니', '멀로', '입었을', '때', '간지', '가', '나긴', '합니다'], ['귀여워요', '보는것처럼', '똑같아요', '오버', '사이', '즈', '일', '줄', '알고있었구요'], ['동', '가격', '대', '중', '색감', '이', '제일', '이쁩니다', '차콜', '이', '너무', '어두', '지', '않게', '잘', '나왔어요', '모자', '조절', '끈', '이', '길어', '따로', '묶어야', '합니다'], ['여성', '사이즈', '구매', '했는데', ',', '기장', '이', '조금', '긴', '것', '같네요', 'ㅠ', '색감', '은', '매우', '좋습니다', '.'], ['어', '두운', '초록색', '이지만', '예쁩니다', '가죽', '재질', '바', '시티', '로', '입기', '좋아요'], ['길이', '는', '딱', '적당한데', '발볼', '이', '조금', '좁아요', '..', '다른', '신발', '들', '신', '을', '때', '웬만하면', '발볼', '이', '좁았던', '적은', '없는데', '이', '거', '는', '편하게', '신으시려면', '1~2', '사이즈', '더', '업', '해서', '신으셔야', '할것', '같아요', '.', '신발', '은', '이뻐요'], ['마음', '에', '듭니', '다', '재질', '이', '좋은', '거', '같아요', '마감', '도', '조아요'], ['굿굿', '아주', '좋아요', '사이즈', '가', '딱', '맞고', '핏', '도', '이쁩니다'], ['음', '한번', '쯤', '구비', '해', '두면', '어떨까', '싶었는데', '할인', '할', '때', '데려왔습니다', '.', '잘', '풀리는거', '빼면', '괜찮은', '듯해', '요'], ['운동', '하', '거나', '집', '앞', '에', '나갈', '때', '입기', '좋습니다', '얇아서', '겨울', '에는', '못', '입어요'], ['심플', '한', '디자인', '에', '오', '버핏', ',', '활용', '성', '굿', '안감', '없는데', '가죽', '이라', '보온', '효과', '는', '있었다', '통통한', '사람', '한테', '도', '적당히', '여유', '있음'], ['블랙', '은', '기', '본', '템', '부드럽고', '좋아요', '재구매', '할', '예정', '이', '예요'], ['교복', '위', '에다가', '입기도', '좋았고', '핏', '도', '이쁘고', '그냥', '기본', '무난', '한', '후드', '티', '인거', '같아요', '회색', '은', '하나', '있어야', '할', '거', '같아서', '샀어요', '이뻐용'], ['허리', '는', '딱', '맞음', '허리', '만', '딱', '맞음', '뭔가', '전체', '적', '으로', '어벙벙', '..?', '롱', '치마', '잘', '안', '입어서', '어색해서', '그런거', '같기', '도해', '용'], ['사진', '이랑', '똑같아요', '데님', '이라', '구기는', '맛', '에', '입고', '다녀요'], ['남자친구', '사줬는데', '엄청', '이뿌네용', '핏', '도', '예뿌', '고', '잘', '사준거', '같아요'], ['자켓안에', '입고', '손목', '한단', '걷어', '올려서', '입으면', '그렇게', '예뻐요'], ['후뚜루', '마뚜루', '입기', '개', '좋음', '블랙프라이데이', '에', '사서', '가성', '비도', '미챴음', '굿', '핏', '도', '좋고', '걍', '굿'], ['짱짱하고', '목도', '탄탄하고', '맘', '에', '듭니', '다', '.', '다만', '변색', '되기', '좀', '쉬운', '재질', '인',  ...

# %% [markdown]
# ## 3-3. 불용어 정제
# 분리된 조사와 이모티콘, 특수문자 등 개체명인식에 필요하지 않은 텍스트를 정제하기 위해 불용어 사전을 별도로 정의하였다.

# %%
all_words_list = sum(train_tokenized, []) # 토큰화한 단어의 리스트를 하나의 리스트로 합침
print(all_words_list)
# Out:
# ['생각', '보다', '무난', '해서', '더', '좋았던것', '같아요', '!', '뭔가', '디테', '일이', '많이', '튈거라고', '생각', '해서', '걱정', '했는데', '사진', '에', '보이는', '색상', '처럼', '괜찮은', '독특한', '블루', '색', '입니다', '기모', '가', '쨩쨩해', '서', '춥진', '않을듯', '합니다', '.', '티셔츠', '안', '에', '받쳐', '입으려면', '노', '기모', '가', '좋을듯', '재질', '도', '좋고', '촉감', '도', '좋습니다', '~', '배송', '역시', '빠르고', '마니', '파세요', '교복', '에', '입기', '정말', '무난', '한', '후드', '집업', 'ㅎㅎ', '사이즈', '도', '넉넉하니', '귀여워요', '생각', '보다', '조금', '얇은', '느낌이긴', '한데', '그래서', '여름', '에', '입기', '좋은', '것', '같아요', '아니', '슬리퍼', '가', '이렇게', '예뻐도', '돼', '나', '만', '신고', '싶다', '진짜', '너무', '예뻐요', '사이즈', '적당하고', '따뜻합니다', '.', '추천', '합니다', '.', '좋네요', '저렴하게', '득템', '했습니다', '.', '코듀', '로', '이', '스커트', '를', '사고싶어', '보다가', '저렴해서', '혹시', '나', '했는데', '받아', '보고', '완전', '만족', '입니다', '.', '^^', '생각', '보다', '너', '~~~~~~', '무', '작아요', '기본', '1', '사이즈', '업햇', '는데', '이건', '2', '사이즈', '업', '필요하겟네요', '부드럽고', '두께', '는', '적당해요', '디자인', '깔끔하고', '하나', '쯤', '있어도', '좋을꺼', '같아요', '굉장히', '도톰하고', '따뜻해요', '엄청', '커서', '몸', '이', '커', '보이', '기는', '하지만', '귀여워', '보여요', '걸', '을', '때', '편하구', '운동화', '에', '포인트', '가', '들어가있어', '넘', '넘', '이뻐요', 'ㅠ', '̑̈', 'ㅠ', '̑̈', '편하고', '좋습니다', '다만', '재봉', '선', '이', '있어서', '불편하실', '수도', '있어요', '저', '는', '편하게', '쓰고', '있습니다', '사이즈', '도', '딱', '맞고', '옷', '도', '너무', '이쁘네요', '옷', '이', '좀', '많이', '얇기', '더', '하고요', '그리고', '사은', '품', '에', '핫팩', '있길래', '주문', '해봤는데', '이미', '쓴', '걸', '로', '오네용', '..', '그냥', '반', '팔', '입', '고', '낄려고', '샀어요', '퀄리티', '는', '가격', '정도', '에요', '딱', '~', '옷', '이', '좋습니다', '잘', '입고', '다니고', '있어요', '~', '감사합니다', '아주', '편하고', '좋아요', '입기도', '편하고', '아주', '시원해요', '미스', '는', '여름', '옷', '을', '겨울', '에', '산', '멍청한', '내', '실수', '보통', '후드', '집업', '크게', '입을려고', '라지', '사는데', '이건', '리뷰', '보고', '긴가민가하면서', '엠', '시켰는데', '널럴하', '니', '딱', '원하는', '핏이', '에여', '!!!', '사이즈', '딱', '적당하고여', '174', '정도', '되시는', '분', '은', 'L', '정도', '가', '딱임다', '엄청', '따뜻해요', '.', '근데', 'm', '은', '허리', '가', '조금', '큰', '것', '같아요', '.', 'S', '사시길', '추천', '!', '치마', '길이', '도', '적당하게', '오고', '입으니까', '이쁜거', '같아요', '~', '어깨', '가', '좀', '많이', '좁아', '보이긴', '합니다만', '미니', '멀로', '입었을', '때', '간지', '가', '나긴', '합니다', '귀여워요', '보는것처럼', '똑같아요', '오버', '사이', '즈', '일', '줄', '알고있었구요', '동', '가격', '대', '중', '색감', '이', '제일', '이쁩니다', '차콜', '이', '너무', '어두', '지', '않게', '잘', '나왔어요', '모자', '조절', '끈', '이', '길어', '따로', '묶어야', '합니다', '여성', '사이즈', '구매', '했는데', ',', '기장', '이', '조금', '긴', '것', '같네요', 'ㅠ', '색감', '은', '매우', '좋습니다', '.', '어', '두운', '초록색', '이지만', '예쁩니다', '가죽', '재질', '바', '시티', '로', '입기', '좋아요', '길이', '는', '딱', '적당한데', '발볼', '이', '조금', '좁아요', '..', '다른', '신발', '들', '신', '을', '때', '웬만하면', '발볼', '이', '좁았던', '적은', '없는데', '이', '거', '는', '편하게', '신으시려면', '1~2', '사이즈', '더', '업', '해서', '신으셔야', '할것', '같아요', '.', '신발', '은', '이뻐요', '마음', '에', '듭니', '다', '재질', '이', '좋은', '거', '같아요', '마감', '도', '조아요', '굿굿', '아주', '좋아요', '사이즈', '가', '딱', '맞고', '핏', '도', '이쁩니다', '음', '한번', '쯤', '구비', '해', '두면', '어떨까', '싶었는데', '할인', '할', '때', '데려왔습니다', '.', '잘', '풀리는거', '빼면', '괜찮은', '듯해', '요', '운동', '하', '거나', '집', '앞', '에', '나갈', '때', '입기', '좋습니다', '얇아서', '겨울', '에는', '못', '입어요', '심플', '한', '디자인', '에', '오', '버핏', ',', '활용', '성', '굿', '안감', '없는데', '가죽', '이라', '보온', '효과', '는', '있었다', '통통한', '사람', '한테', '도', '적당히', '여유', '있음', '블랙', '은', '기', '본', '템', '부드럽고', '좋아요', '재구매', '할', '예정', '이', '예요', '교복', '위', '에다가', '입기도', '좋았고', '핏', '도', '이쁘고', '그냥', '기본', '무난', '한', '후드', '티', '인거', '같아요', '회색', '은', '하나', '있어야', '할', '거', '같아서', '샀어요', '이뻐용', '허리', '는', '딱', '맞음', '허리', '만', '딱', '맞음', '뭔가', '전체', '적', '으로', '어벙벙', '..?', '롱', '치마', '잘', '안', '입어서', '어색해서', '그런거', '같기', '도해', '용', '사진', '이랑', '똑같아요', '데님', '이라', '구기는', '맛', '에', '입고', '다녀요', '남자친구', '사줬는데', '엄청', '이뿌네용', '핏', '도', '예뿌', '고', '잘', '사준거', '같아요', '자켓안에', '입고', '손목', '한단', '걷어', '올려서', '입으면', '그렇게', '예뻐요', '후뚜루', '마뚜루', '입기', '개', '좋음', '블랙프라이데이', '에', '사서', '가성', '비도', '미챴음', '굿', '핏', '도', '좋고', '걍', '굿', '짱짱하고', '목도', '탄탄하고', '맘', '에', '듭니', '다', '.', '다만', '변색', '되기', '좀', '쉬운', '재질', '인', '것', '같습니다', '.', '아주아주', '베이직', '한', '기본', '가디건', '이에요', '주머니', '있어서', '편함', ' ...

# %%
words = Counter(all_words_list) # 각 단어 별 빈도 수 계산.
print(words) # 불용어 사전 정의에 참고하기 위해 확인.
# Out:
# Counter({'이': 710, '에': 528, '도': 519, '.': 481, '가': 343, '너무': 337, '잘': 300, '좋아요': 287, '!': 261, '사이즈': 242, '같아요': 229, '딱': 195, '좀': 190, '는': 186, '생각': 183, '은': 182, '요': 172, '보다': 165, '옷': 158, '것': 151, '핏': 149, '입기': 143, '로': 138, '으로': 137, '때': 122, '입고': 122, '안': 120, '더': 116, '한': 112, '을': 109, '길이': 108, '재질': 106, '구매': 104, '다': 102, '입니다': 101, '~': 94, '예뻐요': 92, '했는데': 91, '좋고': 90, '조금': 90, '좋은': 90, '거': 88, '하고': 85, '이뻐요': 84, '느낌': 84, '디자인': 81, '좋습니다': 78, '진짜': 78, '가격': 77, '마음': 76, '맘': 76, '많이': 75, '이쁘고': 73, '입으면': 73, '편하게': 72, '허리': 72, '무난': 70, '입': 70, '이라': 70, '추천': 68, '색감': 68, ',': 68, '!!': 68, '그래도': 68, '합니다': 66, '오': 66, '그냥': 64, 'ㅎㅎ': 63, '들': 63, '샀는데': 61, '엄청': 60, '있어서': 60, '..': 60, '기장': 60, '고': 58, '제': 58, '좋네요': 57, '들어요': 57, '할': 56, '수': 56, '부분': 56, '해서': 54, '배송': 54, '겨울': 54, '정말': 52, '버핏': 52, '색상': 51, '정도': 51, '감': 51, '두께': 50, '인데': 50, '약간': 49, '살짝': 48, '근데': 47, '저': 46, '만': 45, '있어요': 45, '아주': 45, '만족합니다': 45, '색': 43, '편하고': 43, '제품': 43, '키': 42, '크게': 40, '해': 40, '용': 40, '예쁘고': 40, '자주': 40, '가성': 39, '게': 39, '않고': 39, '서': 38, '이에요': 38, '면': 38, '네': 38, '듯': 38, '라': 38, '를': 37, '괜찮아요': 37, '랑': 37, '선물': 37, '하나': 36, '커서': 36, '큰': 36, '어깨': 36, '이랑': 36, '바지': 36, '여름': 35, '다른': 35, '비': 35, '가을': 35, '나': 33, '완전': 33, '이쁩니다': 33, '처음': 33, '사진': 32, '샀어요': 32, '편해요': 32, '넘': 31, '맞고': 31, '입어도': 31, '하게': 31, '고민': 31, '같습니다': 30, '...': 30, '했어요': 30, 's': 30, '사': 30, '걱정': 29, '걸': 29, '팔': 29, '기': 29, '따뜻하고': 29, '에도': 29, '하지만': 28, 'ㅠ': 28, '주문': 28, '분': 28, '티': 28, '적': 28, '입으려고': 28, 'ㅠㅠ': 28, '인': 27, '에서': 27, '스타일': 27, '운동': 26, '색깔': 26, '여': 26, '이나': 26, '적당하고': 25, '만족': 25, '너': 25, '이쁘네요': 25, '그리고': 25, '예쁩니다': 25, '굿': 25, '편이': 25, '작은': 25, '부드럽고': 24, '다만': 24, '감사합니다': 24, '데': 24, '착용': 24, '의': 24, '색도': 24, '지금': 24, '길어서': 24, '후기': 24, '듭니': 23, '못': 23, '통': 23, '맞아요': 23, '좋아서': 23, '괜찮은': 22, '있습니다': 22, '퀄리티': 22, '본': 22, '편': 22, '엔': 22, '과': 22, '최고': 22, '가볍고': 22, '또': 22, '대비': 22, '예뻐서': 22, '하': 21, '에는': 21, '적당히': 21, '이뻐서': 21, '이고': 21, '하기': 21, '구': 21, '별로': 21, '있는': 21, '한데': 20, '품': 20, '에요': 20, '중': 20, '성': 20, '감도': 20, '막': 20, '소재': 20, '않아서': 20, '실물': 20, 'm': 19, '같네요': 19, '템': 19, '사서': 19, '~~': 19, '요즘': 19, '?': 19, '커요': 19, '브랜드': 19, '후드': 18, '반': 18, '니': 18, '오버': 18, '평소': 18, '어디': 18, '전': 18, '구입': 18, '껴': 18, '지만': 18, '니당': 18, '예쁜': 18, '빠르고': 17, '기본': 17, '치마': 17, '마감': 17, '블랙': 17, '싸게': 17, '나쁘지': 17, '그': 17, '적당한': 17, '쪽': 17, '두': 17, '습': 17, 'ㅋㅋ': 17, '살': 17, '괜찮고': 17, '봄': 17, '좋을': 17, '목': 17, '역시': 16, 'L': 16, '긴': 16, '굿굿': 16, '입어요': 16, '사람': 16, '예요': 16, '같아서': 16, '오래': 16, '일리': 16, '레깅스': 16, '정사': 16, '이즈': 16, '하면': 16, '사고': 16, '예쁘네요': 16, '친구': 16, 'M': 16, '엉덩이': 16, ',,': 16, '자체': 16, '없고': 16, '상품': 16, '예쁘게': 16, '원단': 16, '있고': 16, '만족해요': 16, '이쁜': 16, '와': 16, '일단': 16, '한겨울': 16, '좋은데': 16, 'ㅎ': 16, '기모': 15, '귀여워요': 15, '^^': 15, '몸': 15, '포인트': 15, '보온': 15, '두꺼운': 15, '니트': 15, '까지': 15, '로고': 15, 'xs': 15, '편해서': 15, '손': 15, '코디': 15, '입는': 15, '이쁘게': 15, '이런': 15, '처럼': 14, '굉장히': 14, '따뜻해요': 14, '일': 14, '모자': 14, '롱': 14, '좋음': 14, '길어요': 14, '없어서': 14, '크기': 14, '같은': 14, '원래': 14, '갈': 14, '라인': 14, '바람막이': 14, '후': 14, '보풀': 14, '가볍게': 14, '사이': 13, '대': 13, '제일': 13, '끈': 13, '어': 13, '얇아서': 13, '활용': 13, '그렇게': 13, '주머니': 13, '따뜻해서': 13, '단추': 13, '무게': 13, '시': 13, '휘뚜루마뚜루': 13, '신축': 13, '같고': 13, '셔츠': 13, '자켓': 13, '다리': 13, '들어': 13, '코트': 13, '작게': 13, '이라서': 13, '보면': 13, '굳': 13, '얇은': 12, '했습니다': 12, '보고': 12, '줄': 12, '지': 12, '할인': 12, '위': 12, '전체': 12, '개': 12, '하네요': 12, '드립니다': 12, '긴한데': 12, '교환': 12, '될': 12, '샀습니다': 12, '크긴': 12, '작아서': 12, '보단': 12, '참고': 12, '믿고': 12, '질': 12, '했던': 12, '만족스러워요': 12, '하세요': 12, '따': 12, '다닐': 12, '세': 12, '드': 12, '그거': 12, '여자친구': 12, '들어서': 12, '입기엔': 12, '해도': 12, '라서': 12, '기도': 12, '짧은': 12, '않아요': 12, 'ㅋ': 12, '뭔가': 11, ...

# %%
word_tokens = train_tokenized # 토큰화 한 학습 데이터
file = open("stopwords.csv", "r") # 불용어 사전 파일 오픈
stop_words = file.read().split("\n") # 각 단어는 개행으로 구분되어 있으므로 \n을 구분자로 사용하여 리드
file.close()
result = [] # 결과 저장위한 변수 선언

for i in range(0, len(word_tokens)): # 데이터 길이(문장 갯수만큼 반복)
  result.append([word for word in word_tokens[i] if not word in stop_words]) 
  # 각 문장마다 불용어 사전에 없는 토큰을 result에 append 

print('불용어 제거 전 :',word_tokens) 
print('불용어 제거 후 :',result)
print(stop_words)

# 아래 코드는 데이터 처리 결과를 더 직관적으로 확인하기 위함
temp = pd.DataFrame()
temp['불용어 제거 전'] = word_tokens
temp['불용어 제거 후'] = result
print(temp)
# Out:
# 불용어 제거 전 : [['생각', '보다', '무난', '해서', '더', '좋았던것', '같아요', '!', '뭔가', '디테', '일이', '많이', '튈거라고', '생각', '해서', '걱정', '했는데'], ['사진', '에', '보이는', '색상', '처럼', '괜찮은', '독특한', '블루', '색', '입니다', '기모', '가', '쨩쨩해', '서', '춥진', '않을듯', '합니다', '.', '티셔츠', '안', '에', '받쳐', '입으려면', '노', '기모', '가', '좋을듯'], ['재질', '도', '좋고', '촉감', '도', '좋습니다', '~', '배송', '역시', '빠르고', '마니', '파세요'], ['교복', '에', '입기', '정말', '무난', '한', '후드', '집업', 'ㅎㅎ', '사이즈', '도', '넉넉하니', '귀여워요'], ['생각', '보다', '조금', '얇은', '느낌이긴', '한데', '그래서', '여름', '에', '입기', '좋은', '것', '같아요'], ['아니', '슬리퍼', '가', '이렇게', '예뻐도', '돼', '나', '만', '신고', '싶다', '진짜', '너무', '예뻐요'], ['사이즈', '적당하고', '따뜻합니다', '.', '추천', '합니다', '.', '좋네요'], ['저렴하게', '득템', '했습니다', '.', '코듀', '로', '이', '스커트', '를', '사고싶어', '보다가', '저렴해서', '혹시', '나', '했는데', '받아', '보고', '완전', '만족', '입니다', '.', '^^'], ['생각', '보다', '너', '~~~~~~', '무', '작아요', '기본', '1', '사이즈', '업햇', '는데', '이건', '2', '사이즈', '업', '필요하겟네요'], ['부드럽고', '두께', '는', '적당해요', '디자인', '깔끔하고', '하나', '쯤', '있어도', '좋을꺼', '같아요'], ['굉장히', '도톰하고', '따뜻해요', '엄청', '커서', '몸', '이', '커', '보이', '기는', '하지만', '귀여워', '보여요'], ['걸', '을', '때', '편하구', '운동화', '에', '포인트', '가', '들어가있어', '넘', '넘', '이뻐요', 'ㅠ', '̑̈', 'ㅠ', '̑̈'], ['편하고', '좋습니다', '다만', '재봉', '선', '이', '있어서', '불편하실', '수도', '있어요', '저', '는', '편하게', '쓰고', '있습니다'], ['사이즈', '도', '딱', '맞고', '옷', '도', '너무', '이쁘네요', '옷', '이', '좀', '많이', '얇기', '더', '하고요', '그리고', '사은', '품', '에', '핫팩', '있길래', '주문', '해봤는데', '이미', '쓴', '걸', '로', '오네용', '..'], ['그냥', '반', '팔', '입', '고', '낄려고', '샀어요', '퀄리티', '는', '가격', '정도', '에요', '딱', '~'], ['옷', '이', '좋습니다', '잘', '입고', '다니고', '있어요', '~', '감사합니다'], ['아주', '편하고', '좋아요', '입기도', '편하고', '아주', '시원해요', '미스', '는', '여름', '옷', '을', '겨울', '에', '산', '멍청한', '내', '실수'], ['보통', '후드', '집업', '크게', '입을려고', '라지', '사는데', '이건', '리뷰', '보고', '긴가민가하면서', '엠', '시켰는데', '널럴하', '니', '딱', '원하는', '핏이', '에여', '!!!'], ['사이즈', '딱', '적당하고여', '174', '정도', '되시는', '분', '은', 'L', '정도', '가', '딱임다'], ['엄청', '따뜻해요', '.', '근데', 'm', '은', '허리', '가', '조금', '큰', '것', '같아요', '.', 'S', '사시길', '추천', '!'], ['치마', '길이', '도', '적당하게', '오고', '입으니까', '이쁜거', '같아요', '~'], ['어깨', '가', '좀', '많이', '좁아', '보이긴', '합니다만', '미니', '멀로', '입었을', '때', '간지', '가', '나긴', '합니다'], ['귀여워요', '보는것처럼', '똑같아요', '오버', '사이', '즈', '일', '줄', '알고있었구요'], ['동', '가격', '대', '중', '색감', '이', '제일', '이쁩니다', '차콜', '이', '너무', '어두', '지', '않게', '잘', '나왔어요', '모자', '조절', '끈', '이', '길어', '따로', '묶어야', '합니다'], ['여성', '사이즈', '구매', '했는데', ',', '기장', '이', '조금', '긴', '것', '같네요', 'ㅠ', '색감', '은', '매우', '좋습니다', '.'], ['어', '두운', '초록색', '이지만', '예쁩니다', '가죽', '재질', '바', '시티', '로', '입기', '좋아요'], ['길이', '는', '딱', '적당한데', '발볼', '이', '조금', '좁아요', '..', '다른', '신발', '들', '신', '을', '때', '웬만하면', '발볼', '이', '좁았던', '적은', '없는데', '이', '거', '는', '편하게', '신으시려면', '1~2', '사이즈', '더', '업', '해서', '신으셔야', '할것', '같아요', '.', '신발', '은', '이뻐요'], ['마음', '에', '듭니', '다', '재질', '이', '좋은', '거', '같아요', '마감', '도', '조아요'], ['굿굿', '아주', '좋아요', '사이즈', '가', '딱', '맞고', '핏', '도', '이쁩니다'], ['음', '한번', '쯤', '구비', '해', '두면', '어떨까', '싶었는데', '할인', '할', '때', '데려왔습니다', '.', '잘', '풀리는거', '빼면', '괜찮은', '듯해', '요'], ['운동', '하', '거나', '집', '앞', '에', '나갈', '때', '입기', '좋습니다', '얇아서', '겨울', '에는', '못', '입어요'], ['심플', '한', '디자인', '에', '오', '버핏', ',', '활용', '성', '굿', '안감', '없는데', '가죽', '이라', '보온', '효과', '는', '있었다', '통통한', '사람', '한테', '도', '적당히', '여유', '있음'], ['블랙', '은', '기', '본', '템', '부드럽고', '좋아요', '재구매', '할', '예정', '이', '예요'], ['교복', '위', '에다가', '입기도', '좋았고', '핏', '도', '이쁘고', '그냥', '기본', '무난', '한', '후드', '티', '인거', '같아요', '회색', '은', '하나', '있어야', '할', '거', '같아서', '샀어요', '이뻐용'], ['허리', '는', '딱', '맞음', '허리', '만', '딱', '맞음', '뭔가', '전체', '적', '으로', '어벙벙', '..?', '롱', '치마', '잘', '안', '입어서', '어색해서', '그런거', '같기', '도해', '용'], ['사진', '이랑', '똑같아요', '데님', '이라', '구기는', '맛', '에', '입고', '다녀요'], ['남자친구', '사줬는데', '엄청', '이뿌네용', '핏', '도', '예뿌', '고', '잘', '사준거', '같아요'], ['자켓안에', '입고', '손목', '한단', '걷어', '올려서', '입으면', '그렇게', '예뻐요'], ['후뚜루', '마뚜루', '입기', '개', '좋음', '블랙프라이데이', '에', '사서', '가성', '비도', '미챴음', '굿', '핏', '도', '좋고', '걍', '굿'], ['짱짱하고', '목도', '탄탄하고', '맘', '에', '듭니', '다', '.', '다만', '변색', '되기', '좀', '쉬운',  ...
# 불용어 제거 후 : [['무난', '해서', '좋았던것', '같아요', '뭔가', '디테', '일이', '튈거라고', '해서', '걱정'], ['사진', '보이는', '색상', '처럼', '괜찮은', '독특한', '블루', '색', '기모', '쨩쨩해', '서', '춥진', '않을듯', '합니다', '티셔츠', '받쳐', '입으려면', '노', '기모', '좋을듯'], ['재질', '좋고', '촉감', '좋습니다', '배송', '역시', '빠르고', '마니', '파세요'], ['교복', '입기', '정말', '무난', '후드', '집업', '사이즈', '넉넉하니', '귀여워요'], ['얇은', '느낌이긴', '여름', '입기', '좋은', '같아요'], ['슬리퍼', '이렇게', '예뻐도', '돼', '만', '신고', '싶다', '예뻐요'], ['사이즈', '적당하고', '따뜻합니다', '추천', '합니다', '좋네요'], ['저렴하게', '득템', '했습니다', '코듀', '스커트', '사고싶어', '보다가', '저렴해서', '받아', '보고', '완전', '만족'], ['무', '작아요', '기본', '1', '사이즈', '업햇', '는데', '이건', '2', '사이즈', '업', '필요하겟네요'], ['부드럽고', '두께', '는', '적당해요', '디자인', '깔끔하고', '쯤', '있어도', '좋을꺼', '같아요'], ['굉장히', '도톰하고', '따뜻해요', '엄청', '커서', '몸', '커', '기는', '귀여워', '보여요'], ['걸', '편하구', '운동화', '포인트', '들어가있어', '넘', '넘', '이뻐요', '̑̈', '̑̈'], ['편하고', '좋습니다', '재봉', '선', '있어서', '불편하실', '수도', '있어요', '는', '편하게', '쓰고', '있습니다'], ['사이즈', '맞고', '이쁘네요', '얇기', '하고요', '사은', '품', '핫팩', '있길래', '주문', '해봤는데', '이미', '쓴', '걸', '오네용'], ['그냥', '반', '팔', '고', '낄려고', '샀어요', '퀄리티', '는', '가격', '에요'], ['좋습니다', '입고', '다니고', '있어요', '감사합니다'], ['아주', '편하고', '좋아요', '입기도', '편하고', '아주', '시원해요', '미스', '는', '여름', '겨울', '산', '멍청한', '실수'], ['보통', '후드', '집업', '크게', '입을려고', '라지', '사는데', '이건', '리뷰', '보고', '긴가민가하면서', '엠', '시켰는데', '널럴하', '니', '원하는', '핏이', '에여'], ['사이즈', '적당하고여', '174', '되시는', '분', 'L', '딱임다'], ['엄청', '따뜻해요', '근데', 'm', '허리', '큰', '같아요', 'S', '사시길', '추천'], ['치마', '길이', '적당하게', '오고', '입으니까', '이쁜거', '같아요'], ['어깨', '좁아', '보이긴', '합니다만', '미니', '멀로', '입었을', '간지', '나긴', '합니다'], ['귀여워요', '보는것처럼', '똑같아요', '오버', '사이', '즈', '줄', '알고있었구요'], ['동', '가격', '대', '색감', '제일', '이쁩니다', '차콜', '어두', '않게', '나왔어요', '모자', '조절', '끈', '길어', '따로', '묶어야', '합니다'], ['여성', '사이즈', '구매', '기장', '긴', '같네요', '색감', '매우', '좋습니다'], ['두운', '초록색', '예쁩니다', '가죽', '재질', '바', '시티', '입기', '좋아요'], ['길이', '는', '적당한데', '발볼', '좁아요', '신발', '신', '웬만하면', '발볼', '좁았던', '적은', '없는데', '는', '편하게', '신으시려면', '1~2', '사이즈', '업', '해서', '신으셔야', '할것', '같아요', '신발', '이뻐요'], ['마음', '듭니', '재질', '좋은', '같아요', '마감', '조아요'], ['굿굿', '아주', '좋아요', '사이즈', '맞고', '핏', '이쁩니다'], ['음', '한번', '쯤', '구비', '해', '두면', '어떨까', '싶었는데', '할인', '데려왔습니다', '풀리는거', '빼면', '괜찮은', '듯해'], ['운동', '거나', '나갈', '입기', '좋습니다', '얇아서', '겨울', '에는', '못', '입어요'], ['심플', '디자인', '버핏', '활용', '성', '굿', '안감', '없는데', '가죽', '보온', '효과', '는', '있었다', '통통한', '한테', '적당히', '여유', '있음'], ['블랙', '기', '본', '템', '부드럽고', '좋아요', '재구매', '예정', '예요'], ['교복', '위', '에다가', '입기도', '좋았고', '핏', '이쁘고', '그냥', '기본', '무난', '후드', '티', '인거', '같아요', '회색', '있어야', '같아서', '샀어요', '이뻐용'], ['허리', '는', '맞음', '허리', '만', '맞음', '뭔가', '전체', '어벙벙', '롱', '치마', '입어서', '어색해서', '그런거', '같기', '도해', '용'], ['사진', '이랑', '똑같아요', '데님', '구기는', '맛', '입고', '다녀요'], ['남자친구', '사줬는데', '엄청', '이뿌네용', '핏', '예뿌', '고', '사준거', '같아요'], ['자켓안에', '입고', '손목', '한단', '걷어', '올려서', '그렇게', '예뻐요'], ['후뚜루', '마뚜루', '입기', '좋음', '블랙프라이데이', '사서', '가성', '비도', '미챴음', '굿', '핏', '좋고', '걍', '굿'], ['짱짱하고', '목도', '탄탄하고', '맘', '듭니', '변색', '되기', '쉬운', '재질', '인', '같습니다'], ['아주아주', '베이직', '기본', '가디건', '이에요', '주머니', '있어서', '편함'], ['길이', '는', '길어요', '부드럽도', '따뜻해서', '좋습니다'], ['허리', '크네요', '이뻐서', '만족합니다', '입을꺼', '같아요'], ['길이', '길었지만', '수선해서', '입으니까', '괜찮았습니다'], ['여름', '내내', '입고', '다녔습니다', '아무', '받쳐', '입기', '좋아요'], ['착용', '감도', '편하고', '예쁩니다', '이제', '더워지는데', '입을가', '같아여'], ['사이즈', '좋아요', '허벅지', '굵어서', '큰', '사이즈', '허리', '큰', '편', '아니예요', '이뻐요'], ['휘뚜루', '마뚜루', '있어요', '오래', '는', '없을거', '같아요', '재질', '금방', '닳는게', '느껴져요'], ['블프때', '싸게', '샀어요', '품', '크게', '나왔구요', 'L', '사이즈', '면', '충분히', '후드', '입을만', '해보여요', '밑단스트링', '있어서', '좋구요', '주머니', '단추', '인', '건', '아쉬웠어요', '입을게요'], ['핏', '색상', '그냥', '모든', '게', '족', '크리스마스', '데이트', '기념', '산건데', '샀어요'], ['키', '작은데도', '수선할', '는', '아니네요', '가끔', '롱', '스커트', '수선하기도', '하는데'], ['바지', '에서도', '보플', '생기는게', '특이한데', '편하게', '있어요'], ['무거워', '이쁘고', '옆면', '단추', '열리네요'], ['흰색', '기', '본', '티', '입기', '무난', '좋습니다', '이쁩니다'], ['탐나서', '사긴', '겨울', '여러', '겹', '입다', '보니', '하질', '못', '하네요'], ['사이즈', '크게', '샀더니', '두꺼운', '니트', '후드', '티', '입고도', '널널해', '10월', '11월', '입으려고', '샀는데', '아 ...
# ['ㄱ', 'ㄴ', 'ㄷ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅅ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ', 'ㅋㅋ', 'ㅎㅎ', 'ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅜㅜ', 'ㅠ', 'ㅠㅠ', 'ㅡ', 'ㅣ', 'ㅢ', 'ㅐ', 'ㅒ', 'ㅔ', 'ㅖ', '~', '~~', '~~~', '~~~~', '~~~~~', '~~~~~~', '?', '??', '???', '!', '!!', '!!!', '!!!!', '!!!!!', '!!!!!!', '@', '#', '$', '%', '^', '^^', '&', '*', '(', ')', '-', '_', '=', '+', ':', ';', '.', '..', '...', '…', '..?', ',', ',,', ',,,', '><', '아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라', '의해', '을', '를', '에', '의', '가', '으로', '로', '에게', '뿐이다', '의거하여', '근거하여', '입각하여', '기준으로', '예하면', '예를 들면', '예를 들자면', '저', '소생', '저희', '지말고', '하지마', '하지마라', '다른', '물론', '또한', '그리고', '비길수 없다', '해서는 안된다', '뿐만 아니라', '만이 아니다', '만은 아니다', '막론하고', '관계없이', '그치지 않다', '그러나', '그런데', '하지만', '든간에', '논하지 않다', '따지지 않다', '설사', '비록', '더라도', '아니면', '만 못하다', '하는 편이 낫다', '불문하고', '향하여', '향해서', '향하다', '쪽으로', '틈타', '이용하여', '타다', '오르다', '제외하고', '이 외에', '이 밖에', '하여야', '비로소', '한다면 몰라도', '외에도', '이곳', '여기', '부터', '기점으로', '따라서', '할 생각이다', '하려고하다', '이리하여', '그리하여', '그렇게 함으로써', '하지만', '일때', '할때', '앞에서', '중에서', '보는데서', '으로써', '로써', '까지', '해야한다', '일것이다', '반드시', '할줄알다', '할수있다', '할수있어', '임에 틀림없다', '한다면', '등', '등등', '제', '겨우', '단지', '다만', '할뿐', '딩동', '댕그', '대해서', '대하여', '대하면', '훨씬', '여', '약간', '다소', '좀', '조금', '다수', '지만', '하물며', '또한', '그러나', '그렇지만', '하지만', '이외에도', '대해 말하자면', '뿐이다', '다음에', '반대로', '반대로 말하자면', '이와 반대로', '바꾸어서 말하면', '바꾸어서 한다면', '만약', '그렇지않으면', '까악', '툭', '딱', '삐걱거리다', '보드득', '비걱거리다', '꽈당', '응당', '해야한다', '에 가서', '각', '각각', '여러분', '각종', '각자', '제각기', '하도록하다', '와', '과', '그러므로', '그래서', '고로', '한 까닭에', '하기 때문에', '거니와', '이지만', '대하여', '관하여', '관한', '과연', '실로', '아니나다를가', '생각한대로', '진짜로', '한적이있다', '하곤하였다', '하', '하하', '허허', '아하', '거바', '와', '왜', '어째서', '무엇때문에', '어찌', '하겠는가', '무슨', '어디', '어느곳', '더군다나', '하물며', '더욱이는', '어느때', '언제', '야', '이봐', '어이', '여보시오', '흐흐', '흥', '휴', '헉헉', '헐떡헐떡', '영차', '여차', '어기여차', '끙끙', '아야', '앗', '아야', '콸콸', '졸졸', '좍좍', '뚝뚝', '주룩주룩', '솨', '우르르', '그래도', '또', '그리고', '바꾸어말하면', '바꾸어말하자면', '혹은', '혹시', '답다', '및', '그에 따르는', '때가 되어', '즉', '지든지', '설령', '가령', '하더라도', '할지라도', '일지라도', '지든지', '거의', '하마터면', '인젠', '이젠', '된바에야', '된이상', '만큼\t', '어찌됏든', '그위에', '게다가', '점에서 보아', '비추어 보아', '고려하면', '하게될것이다', '일것이다', '비교적', '좀', '보다더', '비하면', '시키다', '하게하다', '할만하다', '의해서', '연이서', '이어서', '잇따라', '뒤따라', '뒤이어', '결국', '의지하여', '기대여', '통하여', '자마자', '더욱더', '불구하고', '얼마든지', '마음대로', '주저하지 않고', '밖에 안된다', '하면된다', '그래', '그렇지', '요컨대', '다시 말하자면', '바꿔 말하면', '즉', '구체적으로', '말하자면', '시작하여', '시초에', '허', '헉', '허걱', '바와같이', '해도좋다', '해도된다', '게다가', '더구나', '하물며', '와르르', '팍', '퍽', '펄렁', '동안', '이래', '하고있었다', '이었다', '에서', '로부터', '까지', '예하면', '했어요', '해요', '함께', '같이', '더불어', '마저', '마저도', '양자', '모두', '습니다', '가까스로', '하려고하다', '즈음하여', '다른', '다른 방면으로', '해봐요', '습니까', '했어요', '말할것도 없고', '무릎쓰고', '개의치않고', '하는것만 못하다', '하는것이 낫다', '매', '매번', '들', '모', '어느것', '어느', '로써', '갖고말하자면', '어디', '어느쪽', '어느것', '어느해', '어느 년도', '라 해도', '언젠가', '어떤것', '어느것', '저기', '저쪽', '저것', '그때', '그럼', '그러면', '요만한걸', '그래', '그때', '저것만큼', '그저', '이르기까지', '할 줄 안다', '할 힘이 있다', '너', '너희', '당신', '어찌', '설마', '차라리', '할지언정', '할지라도', '할망정', '할지언정', '구토하다', '게우다', '토하다', '메쓰겁다', '옆사람', '퉤', '쳇', '의거하여', '근거하여', '의해', '따라', '힘입어', '그', '다음', '버금', '두번째로', '기타', '첫번째로', '나머지는', '그중에서', '견지에서', '형식으로 쓰여', '입장에서', '위해서', '단지', '의해되다', '하도록시키다', '뿐만아니라', '반대로', '전후', '전자', '앞의것', '잠시', '잠깐', '하면서', '그렇지만', '다음에', '그러한즉', '그런즉', '남들', '아무거나', '어찌하든지', '같다', '비슷하다', '예컨대', '이럴정도로', '어떻게', '만약', '만일', '위에서 서술한바와같이', '인 듯하다', '하지 않는다면', '만약에', '무엇', '무슨', '어느', '어떤', '아래윗', '조차', '한데', '그럼에도 불구하고', '여전히', '심지어', '까지도', '조차도', '하지 않도록', '않기 위하여', '때', '시각', '무렵', '시간', '동안', '어때', '어떠한', '하여금', '네', '예', '우선', '누구', '누가 알겠는가', '아무도', '줄은모른다', '줄은 몰랏다', '하는 김에', '겸사겸사', '하는바', '그런 까닭에', '한 이유는', '그러니', '그러니까', '때문에', '그', '너희', '그들', '너희들', '타인', '것', '것들', '너', '위하여', '공동으로', '동시에', '하기 위하여', '어찌하여', '무엇때문에', '붕붕', '윙윙', '나', '우리', '엉엉', '휘익', '윙윙', '오호', '아하', '어쨋든', '만 못하다', '하기보다는', '차라리', '하는 편이 낫다', '흐흐', '놀라다', '상대적으로 말하자면', '마치', '아니라면', '쉿', '그렇지 않으면', '그렇지 않다면', '안 그러면', '아니었다면', '하든지', '아니면', ...
#                                                불용어 제거 전                                           불용어 제거 후
# 0     [생각, 보다, 무난, 해서, 더, 좋았던것, 같아요, !, 뭔가, 디테, 일이, ...      [무난, 해서, 좋았던것, 같아요, 뭔가, 디테, 일이, 튈거라고, 해서, 걱정]
# 1     [사진, 에, 보이는, 색상, 처럼, 괜찮은, 독특한, 블루, 색, 입니다, 기모,...  [사진, 보이는, 색상, 처럼, 괜찮은, 독특한, 블루, 색, 기모, 쨩쨩해, 서,...
# 2     [재질, 도, 좋고, 촉감, 도, 좋습니다, ~, 배송, 역시, 빠르고, 마니, 파세요]           [재질, 좋고, 촉감, 좋습니다, 배송, 역시, 빠르고, 마니, 파세요]
# 3     [교복, 에, 입기, 정말, 무난, 한, 후드, 집업, ㅎㅎ, 사이즈, 도, 넉넉하...          [교복, 입기, 정말, 무난, 후드, 집업, 사이즈, 넉넉하니, 귀여워요]
# 4     [생각, 보다, 조금, 얇은, 느낌이긴, 한데, 그래서, 여름, 에, 입기, 좋은,...                        [얇은, 느낌이긴, 여름, 입기, 좋은, 같아요]
# ...                                                 ...                                                ...
# 1574  [제, 가, 가슴, 이, 좀, 있는, 편, 이어서, 한, 사이즈, 크게, 샀는데, ...       [가슴, 있는, 편, 사이즈, 크게, 샀는데, 원하는, 사이즈, 핏, 였, 음]
# 1575  [스몰, 로, 샀는데도, 넉넉한, 기장, ,, 품, ,, 핏입니, 다, ., 오, ...  [스몰, 샀는데도, 넉넉한, 기장, 품, 핏입니, 버핏, 확실하고, 무겁습니다, 활...
# 1576  [유튜버분, 의, 착용샷, 을, 보고, 구매, 했는데, 받아, 보니, 색감, 이, ...   [유튜버분, 착용샷, 보고, 구매, 받아, 보니, 색감, 선명하고, 편하고, 이쁩니다]
# 1577             [너무, 이쁘고, 패셔너블, 하네오, 무조건, 사시는거, 추천, !]                    [이쁘고, 패셔너블, 하네오, 무조건, 사시는거, 추천]
# 1578  [실, 측, 사이즈, 만, 봤을, 때, 작을까봐, 걱정, 했는데, 오, 버핏, 으로...  [실, 측, 사이즈, 만, 봤을, 작을까봐, 걱정, 버핏, 으로나, 와서, 껴, 입...
#
# [1579 rows x 2 columns]

# %%
print(max(len(l) for l in word_tokens)) # 불용어 처리 전 문장의 최대 길이 : 130
print(max(len(l) for l in result)) # 불용어 처리 후 문장의 최대 길이 : 81
# Out:
# 130
# 81

# %%
temp.to_csv("stopwords_processed.csv", index = None)

# %%
train_text = result
len(train_text)
# Out:
# 1579

# %% [markdown]
# ## 3-4. 태깅(Tagging)
# 불용어를 정제한 데이터에 각 토큰마다 태그를 작성하였다. 정의한 태그는 다음과 같다.
#
# *   사이즈 SIZ / Size
# *   만족도 SAT / Satisfaction
# *   디자인 DES / Design
# *   색상 COL / Color
# *   가격 PRC / Price
# *   착용감 COW / Comfort of wearing
# *   품질 QLT / Quality
# *   소재 MTR / Meterial
# *   코디 COD / Coordinate
# *   관리 MNG / Manage
# *   무게 WGT / Weight
# *   보온성 TMP / Temperature
# *   배송 DLV / Delivery
#
# 태그는 BIO 표현방식을 따르며, 개체가 시작되는 지점은 B(Begin), 개체에 포함 되는 부분은 I(Inside), 개체가 아닌 부분은 O(Outside)로 표기한다. 예를 들어 '사이즈', '커요', '정말'이라는 토큰이 연속해서 있을 경우 각각 'B-SIZ', 'I-SIZ', 'O'로 태깅한다.

# %%
f = open("train_tagging.txt", "w")
for sentence in train_text:
  for token in sentence:
    f.write(token)
    f.write("\n")
  f.write("\n")  
f.close

# %%
# 태깅 분업을 위한 파일 분리

f = open("tagging_kim.txt", "w")
for sentence in train_text[0:226]:
  for token in sentence:
    f.write(token)
    f.write("\n")
  f.write("\n")  
f.close

f = open("tagging_um.txt", "w")
for sentence in train_text[226:452]:
  for token in sentence:
    f.write(token)
    f.write("\n")
  f.write("\n")  
f.close

f = open("tagging_leek.txt", "w")
for sentence in train_text[452:678]:
  for token in sentence:
    f.write(token)
    f.write("\n")
  f.write("\n")  
f.close

f = open("tagging_lees.txt", "w")
for sentence in train_text[678:904]:
  for token in sentence:
    f.write(token)
    f.write("\n")
  f.write("\n")  
f.close

f = open("tagging_lim.txt", "w")
for sentence in train_text[904:1129]:
  for token in sentence:
    f.write(token)
    f.write("\n")
  f.write("\n")  
f.close

f = open("tagging_jo.txt", "w")
for sentence in train_text[1129:1354]:
  for token in sentence:
    f.write(token)
    f.write("\n")
  f.write("\n")  
f.close

f = open("tagging_ha.txt", "w")
for sentence in train_text[1354:1579]:
  for token in sentence:
    f.write(token)
    f.write("\n")
  f.write("\n")  
f.close

# %%
import re # 정규표현식 사용 위함
import matplotlib.pyplot as plt # 도표 시각화 위함

# %%
f = open('tagging_complete.txt', 'r')
tagged_sentences = []
sentence = []

for line in f:
    if len(line)==0 or line[0]=="\n":
        if len(sentence) > 0:
            tagged_sentences.append(sentence)
            sentence = []
        continue
    splits = line.split(' ') # 공백을 기준으로 속성을 구분한다.
    splits[-1] = re.sub(r'\n', '', splits[-1]) # 줄바꿈 표시 \n을 제거한다.
    word = splits[0]
    sentence.append([word, splits[-1]]) # 단어와 개체명 태깅만 기록한다.

print(tagged_sentences)
print("전체 문장 개수: ", len(tagged_sentences))
# Out:
# [[['무난', 'B-DES'], ['해서', 'I-DES'], ['좋았던', 'I-DES'], ['같아요', 'O'], ['뭔가', 'O'], ['디테', 'B-DES'], ['일이', 'I-DES'], ['튈', 'I-DES'], ['라고', 'O'], ['해서', 'O'], ['걱정', 'O']], [['사진', 'O'], ['보이는', 'O'], ['색상', 'B-COL'], ['처럼', 'O'], ['괜찮은', 'O'], ['독특한', 'O'], ['블루', 'B-COL'], ['색', 'I-COL'], ['기모', 'B-MTR'], ['쨩쨩해', 'I-MTR'], ['서', 'O'], ['춥진', 'B-TMP'], ['않을듯', 'O'], ['합니다', 'O'], ['티셔츠', 'B-COD'], ['받쳐', 'I-COD'], ['입으려면', 'O'], ['노기로', 'O'], ['좋을', 'O'], ['듯', 'O']], [['재질', 'B-MTR'], ['좋고', 'B-SAT'], ['촉감', 'B-MTR'], ['좋습니다', 'B-SAT'], ['배송', 'B-DLV'], ['역시', 'O'], ['빠르고', 'B-DLV'], ['파세요', 'O']], [['교복', 'B-COD'], ['입기', 'I-COD'], ['정말', 'O'], ['무난', 'B-DES'], ['후드', 'O'], ['집업', 'O'], ['사이즈', 'B-SIZ'], ['넉넉하니', 'I-SIZ'], ['귀여워요', 'O']], [['얇은', 'B-MTR'], ['느낌이긴', 'O'], ['여름', 'B-TMP'], ['입기', 'O'], ['좋은', 'O'], ['같아요', 'O']], [['슬리퍼', 'O'], ['이렇게', 'O'], ['예뻐도', 'B-SAT'], ['돼', 'O'], ['만', 'O'], ['신고', 'O'], ['싶다', 'O'], ['예뻐요', 'B-SAT']], [['사이즈', 'B-SIZ'], ['적당하고', 'O'], ['따뜻합니다', 'B-TMP'], ['추천', 'B-SAT'], ['합니다', 'O'], ['좋네요', 'B-SAT']], [['저렴하게', 'B-PRC'], ['득템', 'O'], ['했습니다', 'O'], ['코듀', 'B-MTR'], ['로이', 'I-MTR'], ['스커트', 'O'], ['사고', 'O'], ['싶어', 'O'], ['보다가', 'O'], ['저렴해서', 'B-PRC'], ['받아', 'O'], ['보고', 'O'], ['완전히', 'O'], ['만족', 'B-SAT']], [['무', 'O'], ['작아요', 'B-SIZ'], ['기본', 'O'], ['1', 'B-SIZ'], ['사이즈', 'I-SIZ'], ['업', 'O'], ['이건', 'O'], ['2', 'B-SIZ'], ['사이즈', 'I-SIZ'], ['업', 'O'], ['필요하겠네요', 'O']], [['부드럽고', 'B-MTR'], ['두께', 'I-MTR'], ['는', 'O'], ['적당해요', 'O'], ['디자인', 'B-DES'], ['깔끔하고', 'I-DES'], ['쯤', 'O'], ['있어도', 'O'], ['좋을', 'O'], ['같아요', 'O']], [['굉장히', 'O'], ['도톰하고', 'B-MTR'], ['따뜻해요', 'B-TMP'], ['엄청', 'O'], ['커서', 'B-SIZ'], ['몸', 'O'], ['커', 'O'], ['기는', 'O'], ['귀여워', 'O'], ['보여요', 'O']], [['걸', 'O'], ['편하고', 'B-COW'], ['운동화', 'O'], ['포인트', 'B-DES'], ['들어가', 'O'], ['있어', 'O'], ['넘', 'O'], ['넘', 'O'], ['이뻐요', 'B-SAT'], ['̑̈', 'O'], ['̑̈', 'O']], [['편하고', 'B-COW'], ['좋습니다', 'I-COW'], ['재봉', 'B-COW'], ['선', 'I-COW'], ['있어서', 'I-COW'], ['불편하실', 'I-COW'], ['수도', 'O'], ['있어요', 'O'], ['는', 'O'], ['편하게', 'B-COW'], ['쓰고', 'O'], ['있습니다', 'O']], [['사이즈', 'B-SIZ'], ['맞고', 'I-SIZ'], ['이쁘네요', 'B-SAT'], ['얇기도', 'B-MTR'], ['하고요', 'O'], ['사은', 'O'], ['품', 'O'], ['핫팩', 'O'], ['있길래', 'O'], ['주문', 'O'], ['해봤는데', 'O'], ['이미', 'O'], ['쓴', 'O'], ['걸', 'O'], ['오네요', 'O']], [['그냥', 'O'], ['반', 'B-COD'], ['팔', 'I-COD'], ['입고', 'I-COD'], ['끼려고', 'O'], ['샀어요', 'O'], ['퀄리티', 'B-QLT'], ['는', 'O'], ['가격', 'B-PRC'], ['에요', 'O']], [['좋습니다', 'B-SAT'], ['입고', 'O'], ['다니고', 'O'], ['있어요', 'O'], ['감사합니다', 'O']], [['아주', 'O'], ['편하고', 'B-COW'], ['좋아요', 'I-COW'], ['입기도', 'B-COW'], ['편하고', 'I-COW'], ['아주', 'O'], ['시원해요', 'B-TMP'], ['미스', 'O'], ['는', 'O'], ['여름', 'B-TMP'], ['겨울', 'B-TMP'], ['산', 'O'], ['멍청한', 'O'], ['실수', 'O']], [['보통', 'O'], ['후드', 'O'], ['집업', 'O'], ['크게', 'O'], ['입으려고', 'O'], ['라지', 'B-SIZ'], ['사는데', 'O'], ['이건', 'O'], ['리뷰', 'O'], ['보고', 'O'], ['긴가민가하면서', 'O'], ['엠', 'B-SIZ'], ['시켰는데', 'O'], ['널럴하', 'B-SIZ'], ['니', 'O'], ['원하는', 'O'], ['핏', 'B-SIZ'], ['이에요', 'O']], [['사이즈', 'B-SIZ'], ['적당하고요', 'I-SIZ'], ['174', 'B-SIZ'], ['되시는', 'O'], ['분', 'O'], ['L', 'B-SIZ'], ['딱임다', 'O']], [['엄청', 'O'], ['따뜻해요', 'B-TMP'], ['근데', 'O'], ['m', 'B-SIZ'], ['허리', 'B-SIZ'], ['큰', 'I-SIZ'], ['같아요', 'O'], ['S', 'B-SIZ'], ['사시길', 'O'], ['추천', 'O']], [['치마', 'O'], ['길이', 'B-SIZ'], ['적당하게', 'I-SIZ'], ['오고', 'I-SIZ'], ['입으니까', 'O'], ['이쁜', 'B-SAT'], ['같아요', 'O']], [['어깨', 'B-SIZ'], ['좁아', 'I-SIZ'], ['보이긴', 'I-SIZ'], ['합니다만', 'O'], ['미니', 'B-COD'], ['멀로', 'I-COD'], ['입었을', 'I-COD'], ['간지', 'O'], ['나긴', 'O'], ['합니다', 'O']], [['귀여워요', 'B-SAT'], ['보는', 'O'], ['처럼', 'O'], ['똑같아요', 'O'], ['오버', 'B-SIZ'], ['사이즈', 'I-SIZ'], ['줄', 'O'], ['고', 'O'], ['있었고요', 'O']], [['돈', 'O'], ['가격', 'B-PRC'], ['대', 'O'], ['색감', 'B-COL'], ['제일', 'O'], ['이쁩니다', 'B-SAT'], ['차콜', 'B-COL'], ['이어', 'O'], ['두지', 'O'], ['않게', 'O'], ['나왔어요', 'O'], ['모자', 'O'], ['조절', 'O'], ['끈', 'O'], ['길어', 'O'], ['따로', 'O'], ['묶어야', 'O'], ['합니다', 'O']], [['여성', 'O'], ['사이즈', 'B-SIZ'], ['구매', 'O ...
# 전체 문장 개수:  1578

# %%
tagged_sentences[375][14] = ['x', 'O'] # 불용어 처리시 정제되지 못한 이모티콘을 의미 없는 값으로 바꿔줌.

# %%
sentences, ner_tags = [], [] 
for tagged_sentence in tagged_sentences: # 문장들을 1개씩 불러온다.
    sentence, tag_info = zip(*tagged_sentence) # 각 문장의 단어들은 sentence에, 개체명 태깅 정보들은 tag_info에 저장.
    sentences.append(list(sentence)) # 각 문장에서 단어 정보만 저장한다.
    ner_tags.append(list(tag_info)) # 각 문장에서 개체명 태깅 정보만 저장한다.

print('첫번째 문장 :',sentences[0])
print('첫번째 문장의 태그 :',ner_tags[0])
print(len(sentences))
print(len(ner_tags))
# Out:
# 첫번째 문장 : ['무난', '해서', '좋았던', '같아요', '뭔가', '디테', '일이', '튈', '라고', '해서', '걱정']
# 첫번째 문장의 태그 : ['B-DES', 'I-DES', 'I-DES', 'O', 'O', 'B-DES', 'I-DES', 'I-DES', 'O', 'O', 'O']
# 1578
# 1578

# %%
all_tags_list = sum(ner_tags, [])
tags_len = Counter(all_tags_list)
print(tags_len)
# Out:
# Counter({'O': 10224, 'B-SIZ': 1405, 'B-SAT': 1310, 'I-SIZ': 721, 'B-MTR': 458, 'B-TMP': 384, 'B-COW': 342, 'B-COL': 337, 'B-DES': 320, 'I-SAT': 250, 'I-MTR': 189, 'B-COD': 176, 'I-COD': 169, 'I-DES': 165, 'I-COL': 151, 'I-COW': 143, 'B-QLT': 138, 'B-PRC': 131, 'B-WGT': 94, 'I-QLT': 85, 'B-DLV': 70, 'I-PRC': 67, 'I-DLV': 65, 'I-TMP': 54, 'B-MNG': 46, 'I-MNG': 23, 'I-WGT': 23, '': 23})

# %%
# 전체 데이터의 길이 분포 확인
print('리뷰 데이터 최대 길이 : %d' % max(len(sentence) for sentence in sentences))
print('리뷰 데이터 평균 길이 : %f' % (sum(map(len, sentences))/len(sentences)))
plt.hist([len(sentence) for sentence in sentences], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰 데이터 최대 길이 : 82
# 리뷰 데이터 평균 길이 : 11.129911

# %% [markdown]
# 학습용 데이터 중 가장 긴 문장의 82의 길이를 가지며, 주로 40이하의 길이이고 평균적으로 10 내외의 길이를 가짐.

# %% [markdown]
# ## 3-5. 정수 인코딩(Integer Encoding)
# 각 단어에 정수 값을 부여하여 컴퓨터가 연산할 수 있도록 처리하기 위한 작업이다. 이를 위해 단어 빈도 수에 따른 단어 집합을 만들고, 그 순서대로 인덱스를 부여한다.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
 # 토큰화한 적이 없는 단어는 'OOV' (Out-Of-Vocabulary 단어 집합에 없는 단어)로 처리해주기 위해 선언한 파라미터입니다.
src_tokenizer = Tokenizer(oov_token='OOV')
src_tokenizer.fit_on_texts(sentences)

# 태깅 정보 저장
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(ner_tags)  # 문자들을 숫자로 표시

# 문장 데이터에 대해서는 src_tokenizer를, 레이블에 해당되는 개체명 태깅 정보에 대해서는 tar_tokenizer를 사용합니다.
vocab_size = len(src_tokenizer.word_index) + 1  # Tokenizer의 인자로 OOV를 추가해주었기 때문에 1을 더해줍니다.
tag_size = len(tar_tokenizer.word_index) + 1

print('단어 OOV의 인덱스 : {}'.format(src_tokenizer.word_index['OOV']))
print('단어 집합의 크기 : {}'.format(vocab_size))
print('개체명 태깅 정보 집합의 크기 : {}'.format(tag_size))
# Out:
# 단어 OOV의 인덱스 : 1
# 단어 집합의 크기 : 3816
# 개체명 태깅 정보 집합의 크기 : 29

# %%
# 정수 인코딩 수행
X_data = src_tokenizer.texts_to_sequences(sentences)
y_data = tar_tokenizer.texts_to_sequences(ner_tags)

print('첫번째 문장 :',X_data[0])
print('첫번째 문장의 레이블 :',y_data[0])
# Out:
# 첫번째 문장 : [23, 41, 1741, 4, 312, 884, 1169, 1742, 460, 41, 103]
# 첫번째 문장의 레이블 : [9, 14, 14, 1, 1, 9, 14, 14, 1, 1, 1]

# %%
word_to_index = src_tokenizer.word_index 
index_to_word = src_tokenizer.index_word #모델 학습 후 결과 확인을 위해 인덱스로부터 단어를 리턴 합니다.
ner_to_index = tar_tokenizer.word_index 
index_to_ner = tar_tokenizer.index_word #인덱스로부터 개체명 태깅 정보를 리턴 합니다.
index_to_ner[0] = 'PAD'

# 개체명 태깅 정보를 출력합니다.
print(index_to_ner)
# Out:
# {1: 'o', 2: 'b-siz', 3: 'b-sat', 4: 'i-siz', 5: 'b-mtr', 6: 'b-tmp', 7: 'b-cow', 8: 'b-col', 9: 'b-des', 10: 'i-sat', 11: 'i-mtr', 12: 'b-cod', 13: 'i-cod', 14: 'i-des', 15: 'i-col', 16: 'i-cow', 17: 'b-qlt', 18: 'b-prc', 19: 'b-wgt', 20: 'i-qlt', 21: 'b-dlv', 22: 'i-prc', 23: 'i-dlv', 24: 'i-tmp', 25: 'b-mng', 26: 'i-mng', 27: 'i-wgt', 28: '', 0: 'PAD'}

# %%
# 각 문장의 길이를 같게하기 위해 빈공간을 채우는 패딩 작업을 진행합니다.
X_data = pad_sequences(X_data, padding='post')
y_data = pad_sequences(y_data, padding='post')

X_train, X_test, y_train_int, y_test_int = train_test_split(X_data, y_data, test_size=.1, random_state=1000)
# 검증용 데이터로 10%만 추출합니다.
# 훈련 데이터와 테스트 데이터를 9:1의 비율로 분리합니다.

# 레이블에 해당하는 태깅 정보에 대해서 원-핫 인코딩을 수행합니다.
y_train = to_categorical(y_train_int, num_classes=tag_size)
y_test = to_categorical(y_test_int, num_classes=tag_size)

# 각 데이터 크기를 확인 합니다.
print('학습 문장 데이터의 크기 : {}'.format(X_train.shape))
print('학습 태그 데이터(정수 인코딩)의 크기 : {}'.format(y_train_int.shape))
print('학습 태그 데이터(원-핫 인코딩)의 크기 : {}'.format(y_train.shape))
print('검증 문장 데이터의 크기 : {}'.format(X_test.shape))
print('검증 태그 데이터(정수 인코딩)의 크기 : {}'.format(y_test_int.shape))
print('검증 태그 데이터(원-핫 인코딩)의 크기 : {}'.format(y_test.shape))
# Out:
# 학습 문장 데이터의 크기 : (1420, 82)
# 학습 태그 데이터(정수 인코딩)의 크기 : (1420, 82)
# 학습 태그 데이터(원-핫 인코딩)의 크기 : (1420, 82, 29)
# 검증 문장 데이터의 크기 : (158, 82)
# 검증 태그 데이터(정수 인코딩)의 크기 : (158, 82)
# 검증 태그 데이터(원-핫 인코딩)의 크기 : (158, 82, 29)

# %% [markdown]
# # 4. BiLSTM을 이용한 모델링
# 학습 모델은 이 프로젝트의 목적이 리뷰 텍스트의 개체명인식이라는 점을 고려하였을 때, 여러 개의 입력과 여러 개의 출력이 존재하는 다 대 다(Many to many) 구조이므로 순환신경망(RNN)구조로 학습하는 것이 적절하며, 이전 시점과 이후 시점을 모두 고려하여 학습하고 기억할 필요가 있는 데이터를 기억하며 학습하는 BiLSTM이 개체명인식에 가장 적합하다고 판단하였습니다.

# %% [markdown]
# 은닉층과 학습률, 에포크를 조정하며 각 모델의 정확도를 측정한 결과, 은닉층은 256, 학습률은 0.01, 에포크는 7일 때 가장 정확도가 높게 나타났습니다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, InputLayer, Bidirectional, TimeDistributed, Embedding
from tensorflow.keras.optimizers import Adam

embedding_dim = 128
hidden_units = 256

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, mask_zero=True))
model.add(Bidirectional(LSTM(hidden_units, return_sequences=True)))
model.add(TimeDistributed(Dense(tag_size, activation=('softmax'))))
model.compile(loss='categorical_crossentropy', optimizer=Adam(0.01), metrics=['accuracy'])

history = model.fit(X_train, y_train, batch_size=128, epochs=7, validation_split=0.1)
# Out:
# Epoch 1/7
# 10/10 [==============================] - 38s 2s/step - loss: 0.3231 - accuracy: 0.5190 - val_loss: 0.2539 - val_accuracy: 0.5908
# Epoch 2/7
# 10/10 [==============================] - 18s 2s/step - loss: 0.2319 - accuracy: 0.5891 - val_loss: 0.2212 - val_accuracy: 0.6165
# Epoch 3/7
# 10/10 [==============================] - 19s 2s/step - loss: 0.1768 - accuracy: 0.6599 - val_loss: 0.1843 - val_accuracy: 0.6887
# Epoch 4/7
# 10/10 [==============================] - 18s 2s/step - loss: 0.1271 - accuracy: 0.7578 - val_loss: 0.1552 - val_accuracy: 0.7419
# Epoch 5/7
# 10/10 [==============================] - 19s 2s/step - loss: 0.0884 - accuracy: 0.8161 - val_loss: 0.1433 - val_accuracy: 0.7645
# Epoch 6/7
# 10/10 [==============================] - 17s 2s/step - loss: 0.0627 - accuracy: 0.8576 - val_loss: 0.1447 - val_accuracy: 0.7731
# Epoch 7/7
# 10/10 [==============================] - 17s 2s/step - loss: 0.0475 - accuracy: 0.8868 - val_loss: 0.1513 - val_accuracy: 0.7700

# %% [markdown]
# **return_sequences=True**
# 다 대 다 구조의 양방향 LSTM (또는 레이어를 여러개로 쌓아올릴 때) 사용
#
# **mask_zero=True**
# 리뷰 텍스트 처리와 같이 각 데이터의 길이가 달라서 패딩을 하느라 숫자 0이 많아질 경우에는 숫자 0은 연산에서 제외시킨다는 옵션을 줄 수 있습니다.
#
# **TimeDistributed()**
# LSTM을 다 대 다 구조로 사용하여 LSTM의 모든 시점에 대해서 출력층을 사용할 필요가 있을 때 출력층에 사용합니다.
#
# **validation_split=0.1**
# 훈련 데이터의 10%를 검증 데이터로 분리해서 사용하고, 검증 데이터를 통해서 훈련이 적절히 되고 있는지 확인합니다.
#
# 하이퍼파라미터인 배치 크기는 128이며, 7 에포크를 수행합니다.

# %% [markdown]
# # 5. 결과물 출력

# %%
for i in range(0, 20): # 상위 20개 결과 출력합니다.
    y_predicted = model.predict(np.array([X_test[i]])) # 입력한 테스트용 샘플에 대해서 예측 y를 리턴합니다.
    y_predicted = np.argmax(y_predicted, axis=-1) # 확률 벡터를 정수 인코딩으로 변경합니다.
    labels = np.argmax(y_test[i], -1) # 원-핫 인코딩을 다시 정수 인코딩으로 변경합니다.

    print("{:15}|{:5}|{}".format("\n단어", "실제값", "예측값"))
    print(35 * "-")

    for word, tag, pred in zip(X_test[i], labels, y_predicted[0]):
        if word != 0: # PAD값은 제외합니다.
            print("{:17}: {:7} {}".format(index_to_word[word], index_to_ner[tag], index_to_ner[pred]))
# Out:
# 단어            |실제값  |예측값
# -----------------------------------
# 한겨울              : b-tmp   b-tmp
# 만                : o       o
# 빼면               : o       o
# 초가을              : b-tmp   b-tmp
# 초봄               : b-tmp   o
# 있는               : o       o
# 두께               : b-mtr   b-mtr
# 감                : i-mtr   o
# 아우               : o       o
# 터                : o       o
# 강추               : b-sat   b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 교복               : b-cod   o
# 위                : i-cod   o
# 에다가              : i-cod   o
# 입기도              : i-cod   o
# 좋았고              : o       b-sat
# 핏                : b-siz   b-siz
# 이쁘고              : i-siz   i-siz
# 그냥               : o       o
# 기본               : o       o
# 무난               : b-des   o
# 후드               : o       o
# 티                : o       o
# 인                : o       o
# 같아요              : o       o
# 회색               : b-col   b-col
# 있어야              : o       o
# 같아서              : o       o
# 샀어요              : o       o
# 이뻐요              : b-sat   b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 적당히              : o       o
# 스트리트             : o       o
# 뭔가               : o       o
# 댄디               : o       o
# 있어서              : o       o
# 좋은               : b-sat   o
# 같아요              : o       o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 165              : b-siz   b-siz
# 키                : b-siz   b-siz
# 기준               : o       o
# 이쁜               : b-siz   o
# 길이               : i-siz   b-siz
# 나오고              : o       o
# 촉감               : b-cow   b-cow
# 하지               : o       o
# 못                : o       o
# 질감               : b-mtr   b-mtr
# 이에요              : o       o
# 이쁘고              : b-sat   b-sat
# 좋아요              : i-sat   b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 추울               : b-tmp   b-tmp
# 가볍게              : o       o
# 입고               : o       o
# 다니겠습니다           : o       o
# 감사합니다            : o       o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 따뜻하고             : b-tmp   b-tmp
# 좋습니다             : b-sat   b-sat
# 밖에               : o       o
# 입고               : o       o
# 돌아다니기            : o       o
# 편하고              : b-cow   b-cow
# 좋습니다             : o       b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 이염               : o       o
# 되는               : o       o
# 는                : o       o
# 어쩔               : o       o
# 없는               : o       o
# 같아요              : o       o
# 이쁘고              : b-sat   b-sat
# 기본               : b-cod   o
# 템                : i-cod   o
# 정말               : o       o
# 좋은               : o       o
# 같아요              : o       o
# 굳                : b-sat   b-sat
# 굳                : b-sat   b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 캐시미어             : b-mtr   b-mtr
# 100              : i-mtr   i-mtr
# 라기               : o       o
# 엔                : o       o
# 뻣뻣하지만            : b-mtr   o
# 구                : o       o
# 성비               : o       o
# 괜찮다고             : o       o
# 합니다              : o       o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 좋아요              : b-sat   b-sat
# 포인트              : b-des   o
# 되면서도             : o       o
# 편한               : b-cow   b-cow
# 👍                : o       o
# 겨울               : b-tmp   b-tmp
# 입기엔              : o       o
# 구멍               : o       o
# 사이               : o       o
# 바람               : b-tmp   b-tmp
# 슝슝               : o       o
# 👋                : o       o
# 쨌든               : o       o
# 좋습니다             : b-sat   b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 가죽               : b-mtr   o
# 재킷               : o       o
# 처음               : o       o
# 사봤는데             : o       o
# 괜찮아요             : b-sat   b-sat
# 핏                : b-siz   b-siz
# 예쁘고              : i-siz   b-sat
# 추워서              : b-tmp   b-tmp
# 못                : o       o
# 입고               : o       o
# 있지만              : o       o
# 가을               : b-tmp   b-tmp
# 엄청               : o       o
# 입고               : o       o
# 다닐듯              : o       o
# 합니다              : o       o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 가볍게              : o       o
# 입고               : o       o
# 다닐               : o       o
# 같아요              : o       o
# 짱짱하니             : b-mtr   o
# 좋아요              : i-mtr   b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 그냥               : o       o
# 썼을               : o       o
# 큰                : b-siz   b-siz
# 줄여               : o       b-siz
# 썼습니다             : o       o
# 일반               : o       o
# 캡                : o       o
# 모자               : o       o
# 인데               : o       o
# 불꽃               : b-des   o
# 마크               : i-des   o
# 대칭성              : b-des   o
# 있어서              : o       o
# 안정감              : o       o
# 주네               : o       o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 허리               : o       b-siz
# 커서               : o       i-siz
# 24               : o       b-siz
# 입어도              : o       o
# 괜찮을              : o       o
# 같아요              : o       o
# 질                : b-qlt   b-qlt
# 좋아서              : i-qlt   i-qlt
# 빨래               : b-mng   b-mng
# 몇                : o       o
# 니깐               : o       o
# 헐었어요             : b-qlt   o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 친구               : o       o
# 선물               : o       o
# 려고               : o       o
# 샀는데              : o       o
# 마음               : b-sat   b-sat
# 들어               : i-sat   i-sat
# 하네요              : o       i-sat
# 가격               : b-prc   b-prc
# 대비               : i-prc   o
# 갠                : o       b-sat
# 찬아요              : o       i-qlt
#
# 단어            |실제값  |예측값
# -----------------------------------
# 사이즈              : b-siz   b-siz
# 맞고               : i-siz   i-siz
# 재질               : b-mtr   b-mtr
# 부드러워서            : i-mtr   i-mtr
# 좋아요              : b-sat   b-sat
# 입고               : o       o
# 있어요              : o       o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 좋은               : o       o
# 버핏               : o       o
# 사이즈              : b-siz   b-siz
# 라                : o       o
# 만족               : b-sat   b-sat
# 정말               : o       o
# 예뻐요              : b-sat   b-sat
# 회색               : b-col   i-col
# 처음               : o       o
# 사서               : o       o
# 걱정               : o       o
# 걱정               : o       o
# 필요               : o       o
# 없을               : o       o
# 예뻐요              : b-sat   b-sat
# ☺️               : o       o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 사이즈              : b-siz   b-siz
# 좋아요              : i-siz   i-siz
# 핏                : b-siz   b-siz
# 이쁘고              : i-siz   i-siz
# 세                : o       o
# 사세요              : o       o
#
# 단어            |실제값  |예측값
# -----------------------------------
# 튀지도              : b-des   o
# 않고               : o       o
# 포인트              : b-des   o
# 이쁘게              : i-des   o
# 드                : o       o
# 있고               : o       o
# 재질               : b-mtr   b-mtr
# 되게               : o       o
# 좋네요              : o       b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 모야               : o       o
# 모야               : o       o
# 체크               : b-des   o
# 완전히              : o       o
# 고급               : b-qlt   b-sat
# 지고               : o       i-sat
# 재질               : b-mtr   b-mtr
# 뜬                : o       i-mtr
# 뜬하고              : o       o
# 좋아요              : b-sat   b-sat
#
# 단어            |실제값  |예측값
# -----------------------------------
# 리                : o       i-siz
# 브랜드              : o       o
# 정말               : o       o
# 좋아하는데            : o       o
# 모자               : o       o
# 이쁘네요             : b-sat   b-sat
# 쓰겠습니다            : o       o

# %% [markdown]
# # 6. 개선방향
# 전체적으로 빈도수가 높은 태그에 대해서는 비교적 정확하게 예측해내는 모습을 볼 수 있었지만, 원천 데이터의 수 자체가 적어 에포크가 높아질수록 특정 시점부터 검증 정확도가 들쭉날쭉해지는 과대적합 현상이 발생하였고, 0.76에서 0.77정도의 값에서 더 이상 높아지지 않았다. 이에 추후 개선할 방향을 제시해보고자 한다.
#
#
#
# 1.   절대적인 표본 크기 확보
#
#
# >  자연어처리 학습에는 최소 수 만개의 데이터가 요구되나, 태깅 작업에 소요되는 시간이 많아 1500여 개의 문장을 태깅하는데 그쳤다. 이후 충분한 시간을 두고 태깅 작업을 하여 1만 개 이상의 데이터를 확보한다면 과대적합 문제는 해소될 것으로 기대된다.
#
#
#
# 2.   태깅 작업의 일관성 확보
#
#
# >  태깅 작업은 결국 사람이 수동으로 해주는 작업이므로 태깅의 기준을 정하더라도 한국어 자연어의 모호성 때문에 태깅을 작성하는 사람의 주관이 주입될 수밖에 없었다. 이에 따라 같은 문맥과 단어에도 다른 태그가 붙은 경우로 인해 학습이 제대로 작동하지 못한 부분이 발생하였다. 태깅 작업에 있어서 조금 더 명확한 기준을 정하는 등의 방편이 필요한 것으로 보인다.
#
#
#
# 3.   전처리 방식 개선
#
#
# >  이 프로젝트에서는 한국어 맞춤법 교정기가 형태소 분석기를 제대로 동작하게끔 만들기 위해 반드시 필요한 것으로 판단하였으나, 오히려 형태소 분석에 어려운 형태로 변환한 경우도 다수 발생하였다. 따라서 리뷰 텍스트에서 자주 등장하는 단어를 별도로 사전에 등록하여 이를 기반으로 맞춤법 교정 및 토큰화가 이루어질 수 있도록 처리하고, 불용어 사전 또한 제거할 단어를 보다 다각적으로 분석하여 정의할 필요가 있을 것으로 보인다.
